# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bsObj, includeUrl):
    includeUrl = urlparse(includeUrl).scheme+"://"+urlparse(includeUrl).netloc
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith("/")):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bsObj, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" or "www" that do
    #not contain the current URL
    for link in bsObj.findAll("a", href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks


def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html, "html.parser")
    externalLinks = getExternalLinks(bsObj, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print("No external links, looking around the site for one")
        domain = urlparse(startingPage).scheme+"://"+urlparse(startingPage).netloc
        internalLinks = getInternalLinks(bsObj, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print("Random external link is: "+externalLink)
    followExternalOnly(externalLink)
            
#Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()
def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = urlparse(siteUrl).scheme+"://"+urlparse(siteUrl).netloc
    bsObj = BeautifulSoup(html, "html.parser")
    internalLinks = getInternalLinks(bsObj,domain)
    externalLinks = getExternalLinks(bsObj,domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)

followExternalOnly("http://oreilly.com")

allIntLinks.add("http://oreilly.com")
getAllExternalLinks("http://oreilly.com")
# Out:
# Random external link is: http://twitter.com/oreillymedia
# Random external link is: https://t.co/Mg7jH0i70G
# Random external link is: https://dev.twitter.com/overview/terms/agreement
# Random external link is: https://business.twitter.com/en/help.html
# Random external link is: https://dev.twitter.com/
# Random external link is: https://t.co/m2WTxZfOav
# Random external link is: https://help.twitter.com/safety-and-security
# Random external link is: https://twitterflightschool.com
# No external links, looking around the site for one
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-6632d9c65871> in <module>()
#      71             getAllExternalLinks(link)
#      72
# ---> 73 followExternalOnly("http://oreilly.com")
#      74
#      75 allIntLinks.add("http://oreilly.com")
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 #Collects a list of all external URLs found on the site
#
# <ipython-input-1-6632d9c65871> in followExternalOnly(startingSite)
#      48
#      49 def followExternalOnly(startingSite):
# ---> 50     externalLink = getRandomExternalLink(startingSite)
#      51     print("Random external link is: "+externalLink)
#      52     followExternalOnly(externalLink)
#
# <ipython-input-1-6632d9c65871> in getRandomExternalLink(startingPage)
#      43         domain = urlparse(startingPage).scheme+"://"+urlparse(startingPage).netloc
#      44         internalLinks = getInternalLinks(bsObj, domain)
# ---> 45         return getRandomExternalLink(internalLinks[random.randint(0,len(internalLinks)-1)])
#      46     else:
#      47         return externalLinks[random.randint(0, len(externalLinks)-1)]
#
# ~/anaconda3/lib/python3.6/random.py in randint(self, a, b)
#     218         """
#     219
# --> 220         return self.randrange(a, b+1)
#     221
#     222     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# ~/anaconda3/lib/python3.6/random.py in randrange(self, start, stop, step, _int)
#     196             return istart + self._randbelow(width)
#     197         if step == 1:
# --> 198             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#     199
#     200         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (0,0, 0)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    try: 
        html = urlopen("https://en.wikipedia.org/wiki/Main_Page"+articleUrl)
    except Exception as e:
        print(e)
    else:
        bsObj = BeautifulSoup(html, "html.parser")
        articleUrl = bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))
        return articleUrl
    return list()
links = getLinks("/wiki/Jessica_Chastain")
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

# [궁금] random.seed() 왜 하죠? 
random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    try: 
        html = urlopen("https://en.wikipedia.org"+articleUrl)
    except Exception as e:
        print(e)
    else:
        bsObj = BeautifulSoup(html, "html.parser")
        articleUrl = bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))
        return articleUrl
    return list()
links = getLinks("/wiki/Jessica_Chastain")
# links = getLinks("/wiki/Main_page/wiki/Jessica_Chastain") # wrong input url - error

while len(links) > 0:
    #link 범위 내에서,무작위로 목록을 뿌려줌 / [궁금] 왜 random을 하는데 중복된 링크를 출력하지 않는지?
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"] 
    
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Helen_Mirren
# /wiki/Rachel_McAdams
# /wiki/Jude_Law
# /wiki/Wayback_Machine
# /wiki/USGS_Maps
# /wiki/GeoNames
# /wiki/Resource_Description_Framework
# /wiki/International_World_Wide_Web_Conference
# /wiki/Geneva
# /wiki/Cantons_of_Switzerland
# /wiki/Aargau
# /wiki/List_of_European_regions_with_alternative_names#A
# /wiki/Asturias
# /wiki/Tumulus
# /wiki/Duggleby_Howe
# /wiki/John_Robert_Mortimer
# /wiki/Provenance
# /wiki/Digital_object_identifier
# /wiki/International_Standard_Serial_Number
# /wiki/135_film
# /wiki/126_film
# /wiki/Ektachrome
# /wiki/16_mm_film
# /wiki/Digital_video
# /wiki/Composite_video
# /wiki/Videocassette#Cassette_formats
# /wiki/Army%E2%80%93Navy_Game
# /wiki/Delaware_Valley
# /wiki/Syracuse_metropolitan_area
# /wiki/Shepard_Settlement,_New_York
# /wiki/Salina,_New_York
# /wiki/North_Syracuse,_New_York
# /wiki/Onondaga_Reservation
# /wiki/Camillus_(village),_New_York
# /wiki/1910_United_States_Census
# /wiki/Washington_(state)
# /wiki/Mount_Skokomish_Wilderness
# /wiki/Olmstead_Place_State_Park
# /wiki/Washington_(state)#Law_and_government
# /wiki/Boulder_River_Wilderness
# /wiki/Griffiths-Priday_Ocean_State_Park
# /wiki/Westport_Light_State_Park
# /wiki/Fay_Bainbridge_Park
# /wiki/Fort_Townsend_State_Park
# /wiki/Pasayten_Wilderness
# /wiki/Washington_Natural_Areas_Program
# /wiki/Klondike_Gold_Rush_National_Historical_Park
# /wiki/Aniakchak_National_Monument_and_Preserve
# /wiki/Bristol_Bay
# /wiki/King_Salmon,_Alaska
# /wiki/Pedro_Bay,_Alaska
# /wiki/Kokhanok,_Alaska
# /wiki/Alaska_Senate
# /wiki/Montana_Senate
# /wiki/Jennifer_Pomnichowski
# /wiki/Democratic_Party_(United_States)
# /wiki/Bill_Clinton
# /wiki/Luxembourg
# /wiki/Jeux_de_la_Francophonie
# /wiki/Commonwealth_Games
# /wiki/Willie_Wood_(bowler)
# /wiki/The_Scotsman
# /wiki/Evening_Times
# /wiki/Oshkosh_Northwestern
# /wiki/Wisconsin
# /wiki/Vietnam_War
# /wiki/Qu%E1%BA%A3ng_Tr%E1%BB%8B
# /wiki/V%C5%A9_Quang
# /wiki/Karl_Shuker
# /wiki/Jon-Erik_Beckjord
# /wiki/Ted_Kennedy
# /wiki/Jimmy_Carter
# /wiki/US_Supreme_Court
# /wiki/Off-year_election
# /wiki/United_States_elections,_1984
# /wiki/United_States_elections,_1899
# /wiki/United_States_Senate_elections,_2012
# /wiki/United_States_House_of_Representatives_elections_in_Georgia,_2012
# /wiki/United_States_presidential_election_in_Georgia,_1956
# /wiki/United_States_elections,_1975
# /wiki/Elections_in_Indiana
# /wiki/United_States_presidential_election_in_Indiana,_1848
# /wiki/Millard_Fillmore
# /wiki/Latin
# /wiki/Grammatical_case
# /wiki/Quechua_language
# /wiki/The_Sparrow_(novel)
# /wiki/International_Standard_Book_Number
# /wiki/Paperback
# /wiki/Kenneth_C._Davis
# /wiki/All_Things_Considered
# /wiki/Joe_Bevilacqua
# /wiki/Equus_(play)
# /wiki/Sunrise_at_Campobello_(play)
# /wiki/Roosevelt_Campobello_International_Park
# /wiki/Sumner_T._Pike
# /wiki/Roosevelt_Campobello_International_Park
# /wiki/Isaac_Roosevelt_(businessman)
# /wiki/Indian_Reorganization_Act
# /wiki/United_States_v._Santa_Fe_Pacific_Railroad_Co.
# /wiki/Federal_Power_Commission_v._Tuscarora_Indian_Nation
# /wiki/Oneida_Indian_Nation_of_New_York_v._County_of_Oneida
# /wiki/Diminishment
# /wiki/Lone_Wolf_v._Hitchcock
# /wiki/Native_American_Rights_Fund
# /wiki/International_Work_Group_for_Indigenous_Affairs
# /wiki/Bantustan
# /wiki/KaNgwane
# /wiki/Republic_of_South_Africa
# /wiki/Brazil%E2%80%93China_relations
# /wiki/Brazil%E2%80%93South_Africa_relations
# /wiki/G8%2B5
# /wiki/Prime_Minister_of_the_United_Kingdom
# /wiki/Culture_of_Scotland
# /wiki/Frankenstein
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Postage_stamp
# /wiki/Postage_stamps_and_postal_history_of_Jersey
# /wiki/Russian_post_offices_in_China
# /wiki/Postage_stamps_and_postal_history_of_the_Netherlands
# /wiki/Postage_stamps_and_postal_history_of_Vatican_City
# /wiki/Vatican_City
# /wiki/Outline_of_the_Catholic_Church
# /wiki/Counter-Reformation
# /wiki/Nun
# /wiki/Sisters_of_St._Joseph
# /wiki/Hawaii
# /wiki/Texas
# /wiki/Anahuac_National_Wildlife_Refuge
# /wiki/Daingerfield_State_Park
# /wiki/Laguna_Atascosa_National_Wildlife_Refuge
# /wiki/McFaddin_and_Texas_Point_National_Wildlife_Refuges
# /wiki/Tyler_State_Park_(Texas)
# /wiki/National_Monument_(United_States)
# /wiki/Bureau_of_Land_Management
# /wiki/United_States_Department_of_the_Army
# /wiki/United_States_military_aircraft_designation_systems
# /wiki/United_States_Army
# /wiki/Under_Secretary_of_the_Navy
# /wiki/Under_Secretary_of_the_Navy
# /wiki/Naval_Facilities_Engineering_Command
# /wiki/Naval_Sea_Systems_Command
# /wiki/Bremerton,_Washington
# /wiki/Pacific_County,_Washington
# /wiki/Ferry_County,_Washington
# /wiki/County_(United_States)
# /wiki/Sheriffs_in_the_United_States
# /wiki/Miami_Police_Department
# /wiki/Santa_Rosa_County_Sheriff%27s_Office
# /wiki/Hillsborough_County_Sheriff%27s_Office
# /wiki/Keystone,_Florida
# /wiki/Odessa,_Florida
# /wiki/Pacific_Islander_(U.S._Census)
# /wiki/Personal_income_in_the_United_States
# /wiki/Aristocracy_(class)
# /wiki/Business_magnate
# /wiki/Social_class_in_Sri_Lanka
# /wiki/Social_class_in_the_Ottoman_Empire
# /wiki/Ottomanism
# /wiki/Ottoman_Reform_Edict_of_1856
# /wiki/Regulation_of_the_Armenian_Nation
# /wiki/Babiali
# /wiki/Minister_(government)
# /wiki/Immigration_minister
# /wiki/Foreign_minister
# /wiki/Appeasement
# /wiki/List_of_books_with_anti-war_themes
# /wiki/Peter_Carter_(author)
# /wiki/Greenaway_Medal
# /wiki/Henry_Wadsworth_Longfellow
# /wiki/Antoine_Wiertz
# /wiki/Anne-Louis_Girodet_de_Roussy-Trioson
# /wiki/Charles_Baudelaire
# /wiki/Carl_Maria_von_Weber
# /wiki/Johann_Peter_Heuschkel
# /wiki/Integrated_Authority_File
# /wiki/Library_classification
# /wiki/Logic_programming
# /wiki/Watson_(computer)
# /wiki/Research_and_development
# /wiki/High_technology
# /wiki/High_tech_(disambiguation)
# /wiki/Hi-Tech_(G.I._Joe)
# /wiki/New_York_City
# /wiki/Walkway_over_the_Hudson
# /wiki/Walkway_Marathon
# /wiki/Dutchess_County,_New_York
# /wiki/Barrytown,_New_York
# /wiki/Shekomeko,_New_York
# /wiki/Millerton,_New_York
# /wiki/Daryl_Hall
# /wiki/Pottstown,_Pennsylvania
# /wiki/Fulton_County,_Pennsylvania
# /wiki/Juniata_River
# /wiki/Chillisquaque_Creek
# /wiki/Towanda_Creek
# /wiki/Sodium
# /wiki/Period_(periodic_table)
# /wiki/Carbon_group
# /wiki/Sulfur
# /wiki/Beryllium
# /wiki/Beryllium_fluoride
# /wiki/Titanium_tetrafluoride
# /wiki/Sodium_metatitanate
# /wiki/Dysprosium_titanate
# /wiki/Oxygen
# /wiki/Eukaryote
# /wiki/Tubulinea
# /wiki/PubMed_Identifier
# /wiki/UK_PubMed_Central
# /wiki/Nucleic_Acids_Research
# /wiki/CODEN
# /wiki/ASTM
# /wiki/ASTM_C_1270
# /wiki/ASTM_F_883
# /wiki/Padlock
# /wiki/Chubb_detector_lock
# /wiki/The_Adventure_of_the_Golden_Pince-Nez
# /wiki/Chatham,_Kent
# /wiki/Borough_of_Dartford
# /wiki/Stone,_Kent
# /wiki/Stone_Crossing_station
# /wiki/Sidcup_railway_station
# /wiki/Grand_Central_Railway
# /wiki/National_Express_East_Anglia
# /wiki/South_Western_Railway_(train_operating_company)
# /wiki/Chiltern_Railways
# /wiki/London_Midland
# /wiki/Rail_Magazine
# /wiki/First_(magazine)
# /wiki/The_New_Paper
# /wiki/The_Straits_Times
# /wiki/OCLC
# /wiki/EZproxy
# /wiki/Arizona
# /wiki/Rodeo%E2%80%93Chediski_Fire
# /wiki/Heber-Overgaard,_Arizona
# /wiki/Fort_Apache_Indian_Reservation
# /wiki/Zuni_Indian_Reservation
# /wiki/Fort_Apache_Indian_Reservation
# /wiki/Yazzi,_Arizona
# /wiki/Tes_Nez_Iah,_Arizona
# /wiki/Mexican_Water,_Arizona
# /wiki/El_Tule,_Arizona
# /wiki/Wide_Ruins,_Arizona
# /wiki/Boneyard,_Arizona
# /wiki/Fort_Apache_Indian_Reservation
# /wiki/Turkey_Creek,_Arizona
# /wiki/Mountain_Standard_Time_Zone
# /wiki/Baja_California_Sur
# /wiki/Tamaulipas
# /wiki/General_Servando_Canales_International_Airport
# /wiki/Ciudad_Mante
# /wiki/Mainero,_Tamaulipas
# /wiki/Tamaulipas
# /wiki/Ismael_Valdez
# /wiki/San_Diego_Padres
# /wiki/1996_National_League_Division_Series
# /wiki/Rick_Honeycutt
# /wiki/Mark_Fidrych
# /wiki/1988_in_baseball
# /wiki/1909_in_baseball
# /wiki/Doubleheader_(baseball)
# /wiki/Louisville_Colonels
# /wiki/History_of_the_Milwaukee_Brewers
# /wiki/History_of_the_Washington_Senators_(1901%E2%80%9360)
# /wiki/1934_Washington_Senators_season
# /wiki/2018_Minnesota_Twins_season
# /wiki/Jim_Kaat
# /wiki/1984_Minnesota_Twins_season
# /wiki/Rod_Carew
# /wiki/Cyclone_Joe_Williams
# /wiki/Pitcher
# /wiki/Disabled_list
# /wiki/Captain_(baseball)
# /wiki/Captain_(sports)
# /wiki/Cricket
# /wiki/Bowls
# /wiki/Richard_II_of_England
# /wiki/Antipope_Clement_VII
# /wiki/Second_Council_of_the_Lateran
# /wiki/First_Council_of_the_Lateran#Text_of_the_Council
# /wiki/Gelasius_II
# /wiki/Pope_Gregory_V
# /wiki/Crescentii
# /wiki/Perugia_Papacy
# /wiki/Pope_Benedict_VIII
# /wiki/Pope_Paul_IV
# /wiki/Pope_Callixtus_III
# /wiki/Antipope_Benedict_XIII
# /wiki/Thomas_More
# /wiki/Roscellinus
# /wiki/Barth%C3%A9lemy_Haur%C3%A9au
# /wiki/Lucan
# /wiki/Dominate
# /wiki/Praetorian_prefecture_of_the_East
# /wiki/Quintus_Clodius_Hermogenianus_Olybrius
# /wiki/Gratian
# /wiki/Merobaudes_(general)
# /wiki/List_of_Roman_Consuls
# /wiki/Publius_Servilius_Vatia_Isauricus_(consul_79_BC)
# /wiki/Curia_Hostilia
# /wiki/Arch_of_Titus
# /wiki/Temple_of_Concord
# /wiki/Second_Punic_War
# /wiki/Jugurthine_War
# /wiki/Pyrrhic_War
# /wiki/Bruttii
# /wiki/Crathis
# /wiki/Core_sample
# /wiki/Hess_Corporation
# /wiki/Phillips_66
# /wiki/Conoco_Inc.
# /wiki/Marland_Oil_Company
# /wiki/Continental_Oil
# /wiki/E._W._Marland
# /wiki/James_S._Davenport
# /wiki/Charles_E._Creager
# /wiki/United_States_of_America
# /wiki/Uniformed_services_of_the_United_States
# /wiki/List_of_countries_by_number_of_military_and_paramilitary_personnel
# /wiki/Brunei
# /wiki/Lebanon
# /wiki/Arab_League
# /wiki/Bedouin_music
# /wiki/Coptic_music
# /wiki/Arabic_hip_hop
# /wiki/Music_of_Syria
# /wiki/Culture_of_Syria
# /wiki/Culture_of_Japan
# /wiki/Meiji_period
# /wiki/List_of_political_figures_of_Meiji_Japan
# /wiki/Matsukata_Masayoshi
# /wiki/Katsura_Tar%C5%8D
# /wiki/Yoshio_Sakurauchi
# /wiki/Bhalchandra_Udgaonkar
# /wiki/International_Standard_Book_Number
# /wiki/ISO_3166-2
# /wiki/Guyana
# /wiki/Malaysia
# /wiki/APEC_Australia_1989
# /wiki/Japan
# /wiki/List_of_Japanese_Nobel_laureates
# /wiki/Satoshi_%C5%8Cmura
# /wiki/Bernardo_Houssay
# /wiki/William_P._Murphy
# /wiki/Konrad_Lorenz
# /wiki/Austrian_Decoration_for_Science_and_Art
# /wiki/Decoration_of_Honour_for_Services_to_the_Republic_of_Austria
# /wiki/President_of_Italy
# /wiki/Prime_Minister_of_France
# /wiki/Monarchy_of_the_Netherlands
# /wiki/France
# /wiki/Krzysztof_Kie%C5%9Blowski
# /wiki/Lin_Cheng-sheng
# /wiki/Oliver_Stone
# /wiki/James_Goldman
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# /wiki/National_Library_of_Vatican_City
# /wiki/Domenico_Passionei
# /wiki/Urbino
# /wiki/Guidobaldo_da_Montefeltro
# /wiki/Duke_of_Urbino
# /wiki/Frederick_II,_Holy_Roman_Emperor
# /wiki/Cividale
# /wiki/Prato_Carnico
# /wiki/Villa_Santina
# /wiki/Udine
# /wiki/Colombia
# /wiki/Colombian_Air_Force
# /wiki/Iraqi_Air_Force
# /wiki/Super_Etendard
# /wiki/Oil_tanker
# /wiki/Coal
# /wiki/Carbon_dioxide_sequestration
# /wiki/Biomass
# /wiki/Camelina
# /wiki/Heinrich_Johann_Nepomuk_von_Crantz
# /wiki/Andr%C3%A9_Levret
# /wiki/Paris
# /wiki/2nd_Armored_Division_(France)
# /wiki/3rd_Armored_Division_(France)
# /wiki/3rd_Algerian_Infantry_Division
# /wiki/61st_Infantry_Division_(France)
# /wiki/21st_Infantry_Division_(France)
# /wiki/68th_Infantry_Division_(France)
# /wiki/37th_Infantry_Division_(France)
# /wiki/12th_Infantry_Division_(France)
# /wiki/4th_Armoured_Division_(France,_1964)
# /wiki/9th_Light_Armoured_Marine_Brigade_(France)
# /wiki/8th_Infantry_Division_(France)
# /wiki/3rd_Armored_Division_(France)
# /wiki/2nd_Infantry_Division_(France)
# /wiki/Battle_of_Chemin_des_Dames
# /wiki/2014_Tour_de_France
# /wiki/Press_Association
# /wiki/Islamic_Republic_News_Agency
# /wiki/Bonn
# /wiki/International_Baccalaureate
# /wiki/Bogot%C3%A1
# /wiki/Gonzalo_Jim%C3%A9nez_de_Quesada
# /wiki/Tierradentro
# /wiki/Meta_Department
# /wiki/List_of_Colombian_Departments_by_area
# /wiki/Cundinamarca_Department
# /wiki/Guaduas
# /wiki/Ubat%C3%A9_Province
# /wiki/Nocaima
# /wiki/Lower_Magdalena_Province
# /wiki/Guaduas
# /wiki/La_Vega,_Cundinamarca
# /wiki/Chocont%C3%A1
# /wiki/Tom%C3%A1s_de_Herrera
# /wiki/Rafael_N%C3%BA%C3%B1ez_(politician)
# /wiki/National_anthem
# /wiki/Bro_Goth_agan_Tasow
# /wiki/Rugby_union_in_Cornwall
# /wiki/Northumberland_Rugby_Football_Union#County_club_competitions
# /wiki/British_and_Irish_Lions
# /wiki/England
# /wiki/Scottish_National_Party
# /wiki/Member_of_the_Scottish_Parliament
# /wiki/Scottish_colonization_of_the_Americas
# /wiki/Fortress_of_Louisbourg
# /wiki/French_colonial_empire
# /wiki/Society_of_Saint-Sulpice
# /wiki/Sulpitius_the_Pious
# /wiki/Society_of_Saint-Sulpice
# /wiki/St._Mary%27s_Seminary
# /wiki/Michael_Joseph_Curley
# /wiki/Roman_Catholic_Archdiocese_of_Baltimore
# /wiki/Cristo_Rey_Jesuit_High_School_(Baltimore)
# /wiki/Colegio_San_Ignacio_de_Loyola_(San_Juan)
# /wiki/Puerto_Rican_Independence_Party
# /wiki/Rub%C3%A9n_Berr%C3%ADos
# /wiki/Filiberto_Ojeda_R%C3%ADos
# /wiki/Tom%C3%A1s_L%C3%B3pez_de_Victoria
# /wiki/Cadets_of_the_Republic
# /wiki/Ram%C3%B3n_Emeterio_Betances
# /wiki/Chloroform
# /wiki/Alfentanil
# /wiki/Paracetamol
# /wiki/Etoricoxib
# /wiki/Miroprofen
# /wiki/U-46619
# /wiki/Prostaglandin_D2
# /wiki/Lipoxin
# /wiki/Glutathione
# /wiki/Phases_of_clinical_research#Phase_III
# /wiki/Discovery_and_development_of_nucleoside_and_nucleotide_reverse-transcriptase_inhibitors
# /wiki/Guanosine
# /wiki/Nucleobase
# /wiki/Deoxyuridine_monophosphate
# /wiki/ChEMBL
# /wiki/Biological_activity
# /wiki/Toxicity
# /wiki/PubMed
# /wiki/Teledermatology
# /wiki/Patient_opinion_leader
# /wiki/Healthcare
# /wiki/Clinical_psychology
# /wiki/Positive_psychology
# /wiki/Wisdom
# /wiki/-phil-
# /wiki/Hyperthermophilia
# /wiki/Thomas_D._Brock
# /wiki/Antibiotics
# /wiki/Tetracycline_antibiotics
# /wiki/Dihydrostreptomycin
# /wiki/ATC_code_J01#J01G
# /wiki/Sulfanilamide
# /wiki/Sulfaphenazole
# /wiki/Delafloxacin
# /wiki/Chelates
# /wiki/Menthol
# /wiki/Epicatechin_gallate
# /wiki/LY-2183240
# /wiki/AMB-FUBINACA
# /wiki/HU-243
# /wiki/Cannabidivarin
# /wiki/Dexanabinol
# /wiki/JWH-019
# /wiki/N-Arachidonoyl_dopamine
# /wiki/PubMed_Identifier
# /wiki/Op-ed
# /wiki/Research_proposal
# /wiki/Request_for_proposal
# /wiki/Enterprise_sales
# /wiki/Project_stakeholder
# /wiki/Organization
# /wiki/Absenteeism
# /wiki/Mobbing
# /wiki/Abusive_power_and_control
# /wiki/Social_influence
# /wiki/PubMed_Identifier
# /wiki/Al_Gore
# /wiki/Citizen_Kane
# /wiki/Metro-Goldwyn-Mayer
# /wiki/Bell_%26_Howell
# /wiki/No%C3%ABl_Coward
# /wiki/Italia_Conti_Academy
# /wiki/St_Aloysius_College,_London
# /wiki/Sixth_form
# /wiki/Education_in_Wales
# /wiki/Education_in_Iceland
# /wiki/Private_education
# /wiki/Ministry_of_Education_(Ontario)
# /wiki/Northern_Ontario_Heritage_Fund
# /wiki/Ontario_Film_Review_Board
# /wiki/Ministry_of_the_Status_of_Women_(Ontario)
# /wiki/Ministry_of_Health_and_Long-Term_Care
# /wiki/Ministry_of_Labour_(Ontario)
# /wiki/Ministry_of_Intergovernmental_Affairs_(Ontario)
# /wiki/Premier_of_Ontario
# /wiki/Political_culture_of_Canada
# /wiki/British_Empire
# /wiki/Ascension_Island
# /wiki/Emirate_of_Transjordan
# /wiki/International_Standard_Book_Number
# /wiki/Modular_arithmetic
# /wiki/Library_of_Congress_Control_Number
# /wiki/Virtual_International_Authority_File
# /wiki/Media_Source_Inc.
# /wiki/Private_equity_firm
# /wiki/Ownership_equity
# /wiki/Share_capital
# /wiki/Open_outcry
# /wiki/Security_market_line
# /wiki/Momentum_(finance)
# /wiki/Price_channels
# /wiki/Marubozu
# /wiki/Bollinger_Bands
# /wiki/Moving_average
# /wiki/Maximum_likelihood
# /wiki/Statistical_error
# /wiki/Mallows%27s_Cp
# /wiki/JSTOR
# /wiki/Embargo_(academic_publishing)
# /wiki/News_embargo#On_articles_in_scientific_journals
# /wiki/Afghanistan
# /wiki/United_States_Geological_Survey
# /wiki/Naval_Postgraduate_School
# /wiki/Federal_Judicial_Center
# /wiki/Curtis_Lynn_Collier
# /wiki/Duke_University_School_of_Law
# /wiki/2017_special_counsel_team
# /wiki/Steele_dossier
# /wiki/International_reactions_to_the_United_States_presidential_election,_2016
# /wiki/Leader_of_the_Opposition_(United_Kingdom)
# /wiki/John_Wodehouse,_1st_Earl_of_Kimberley
# /wiki/Christ_Church,_Oxford
# /wiki/A._J._Ayer
# /wiki/OCLC
# /wiki/McFarland_%26_Company
# /wiki/Journal_of_Information_Ethics
# /wiki/Outline_of_academic_disciplines
# /wiki/Economic_growth
# /wiki/Physical_capital
# /wiki/Financial_capital
# /wiki/Measuring_well-being
# /wiki/Richard_Riordan
# /wiki/First_lieutenant
# /wiki/United_States_Air_Force
# /wiki/Operation_Inherent_Resolve
# /wiki/Battle_of_Nasib_Border_Crossing
# /wiki/Battle_of_Azaz_(2012)
# /wiki/Death_of_Hamza_Ali_Al-Khateeb
# /wiki/Ali_Sadreddine_Al-Bayanouni
# /wiki/Palmyra_offensive_(2017)
# /wiki/Infantry_fighting_vehicle
# /wiki/Bull_(armored_personnel_carrier)
# /wiki/M1117_Armored_Security_Vehicle
# /wiki/Mk_19_grenade_launcher
# /wiki/GBU-12_Paveway_II
# /wiki/Boeing_C-17_Globemaster_III
# /wiki/Cessna_C-106_Loadmaster
# /wiki/Pratt_%26_Whitney_R-1340
# /wiki/Kinner_B-5
# /wiki/Warner_Scarab
# /wiki/Pratt_%26_Whitney_R-2800_Double_Wasp
# /wiki/Alfa_Romeo_135
# /wiki/Brake_specific_fuel_consumption
# /wiki/Lycoming_O-235
# /wiki/Continental_O-200
# /wiki/Packard_V-1650_Merlin
# /wiki/Continental_O-170
# /wiki/Continental_O-520
# /wiki/Aircraft_Diesel_engine
# /wiki/Compression_ignition
# /wiki/Steam_car
# /wiki/List_of_steam_car_makers
# /wiki/Henry_Alonzo_House
# /wiki/American_Civil_War
# /wiki/Montgomery_C._Meigs
# /wiki/Election_Riot_of_1874
# /wiki/Presidency_of_Ulysses_S._Grant#Vicksburg_riots
# /wiki/Samuel_M._Arnell
# /wiki/Confederate_States_of_America
# /wiki/Indian_Territory_in_the_American_Civil_War
# /wiki/Frederick_Douglass
# /wiki/Benjamin_Gratz_Brown
# /wiki/John_Leeds_Kerr
# /wiki/Robert_M._T._Hunter
# /wiki/United_States_House_of_Representatives
# /wiki/List_of_earthquakes_in_the_United_States
# /wiki/1992_Landers_earthquake
# /wiki/1892_Laguna_Salada_earthquake
# /wiki/1892_Vacaville%E2%80%93Winters_earthquakes
# /wiki/1906_Aleutian_Islands_earthquake
# /wiki/1887_Sonora_earthquake
# /wiki/1787_New_Spain_earthquake
# /wiki/2018_Oaxaca_earthquake
# /wiki/Iran_Aseman_Airlines_Flight_3704
# /wiki/Bureau_d%27Enqu%C3%AAtes_et_d%27Analyses_pour_la_S%C3%A9curit%C3%A9_de_l%27Aviation_Civile
# /wiki/China
# /wiki/Economy_of_Gabon
# /wiki/Hardwood
# /wiki/Cedrus
# /wiki/Bow_saw
# /wiki/Society_of_Wood_Engravers
# /wiki/Tongue_and_groove
# /wiki/Hammer-headed_tenon
# /wiki/Steam_bending
# /wiki/Wood_scribe
# /wiki/Molding_(decorative)
# /wiki/Strapwork
# /wiki/Ornament_(art)
# /wiki/Courtyard
# /wiki/Solar_(room)
# /wiki/Single-family_detached_home
# /wiki/Conservatory_(greenhouse)
# /wiki/Centennial_Park_Conservatory
# /wiki/Etobicoke
# /wiki/Father_John_Redmond
# /wiki/St._Basil-the-Great_College_School
# /wiki/Midland_Avenue_Collegiate_Institute
# /wiki/Scarborough,_Toronto
# /wiki/Ontario
# /wiki/Hamilton,_Ontario
# /wiki/Binbrook,_Ontario
# /wiki/Politics_of_Hamilton,_Ontario
# /wiki/Member_of_Parliament
# /wiki/List_of_United_Kingdom_MPs
# /wiki/List_of_MPs_elected_in_the_United_Kingdom_general_election,_1874
# /wiki/Sir_Alexander_Matheson,_1st_Baronet
# /wiki/Inverness_Burghs_(UK_Parliament_constituency)
# /wiki/Linlithgow_and_East_Falkirk_(UK_Parliament_constituency)
# /wiki/East_Kilbride,_Strathaven_and_Lesmahagow_(UK_Parliament_constituency)
# /wiki/Subdivisions_of_Scotland
# /wiki/Climate_of_Scotland
# /wiki/Politics_in_Scotland
# /wiki/Scottish_local_elections,_2007
# /wiki/Scottish_Borders_Council_election,_2007
# /wiki/Ipswich_Borough_Council_election,_2007
# /wiki/Ipswich_Borough_Council_election,_2003
# /wiki/Waveney_District_Council_elections
# /wiki/Independent_(politician)
# /wiki/Scottish_National_Party
# /wiki/Future_of_%C3%85land
# /wiki/Hut_Group
# /wiki/%C3%85landic_Left
# /wiki/Parliament_of_%C3%85land
# /wiki/Parliament_of_Montenegro
# /wiki/World_War_II_in_Yugoslavia
# /wiki/Case_Black
# /wiki/Battle_for_Novi_Pazar
# /wiki/Air_battle_over_Ni%C5%A1
# /wiki/United_States
# /wiki/Latin_language
# /wiki/Apex_(diacritic)
# /wiki/Pokrytie
# /wiki/Diacritic
# /wiki/%C5%98
# /wiki/Unicode
# /wiki/Combining_character
# /wiki/%CC%80
# /wiki/Syriac_alphabet#Letter_alterations
# /wiki/Kayah_Li_alphabet
# /wiki/Cretan_hieroglyphs
# /wiki/Small_seal_script
# /wiki/Ky%C5%ABjitai
# /wiki/Differences_in_Shinjitai_and_Simplified_characters
# /wiki/Ch%E1%BB%AF_N%C3%B4m
# /wiki/Logographic
# /wiki/Japanese_language
# /wiki/Wasei-eigo
# /wiki/JIS_X_0212
# /wiki/Code_page_437
# /wiki/Phi_(letter)
# /wiki/Greek_ligatures
# /wiki/UTF-8
# /wiki/Iran_System_encoding
# /wiki/ISO/IEC_8859-15
# /wiki/Code_page_1102
# /wiki/Synchronous_idle
# /wiki/ASCII
# /wiki/VT220
# /wiki/Wyse
# /wiki/New_York_Stock_Exchange
# /wiki/LIFFE
# /wiki/Euronext
# /wiki/CME_Group
# /wiki/US$
# /wiki/John_F._Kennedy
# /wiki/Marty_Meehan
# /wiki/John_Davis_(Massachusetts_governor)
# /wiki/Manasseh_Cutler
# /wiki/William_Lyman_(congressman)
# /wiki/Charles_Q._Tirrell
# /wiki/Elijah_Brigham
# /wiki/Jeremiah_Nelson
# /wiki/Seth_Hastings
# /wiki/Gideon_Gardner
# /wiki/Lemuel_Williams
# /wiki/John_Holmes_(Maine_politician)
# /wiki/Samuel_Sewall_(congressman)
# /wiki/William_Ely
# /wiki/John_Patrick_Higgins
# /wiki/Gayton_P._Osgood
# /wiki/Edward_Dickinson
# /wiki/William_Eustis
# /wiki/Peter_Buell_Porter
# /wiki/United_States_Assistant_Secretary_of_War
# /wiki/John_Otho_Marsh_Jr.
# /wiki/Kenneth_Rush
# /wiki/John_Bigelow
# /wiki/United_States_Ambassador_to_France#United_States_Envoys_to_France
# /wiki/United_States_Ambassador_to_Texas
# /wiki/Charg%C3%A9_d%27affaires
# /wiki/De_facto_embassy
# /wiki/South_Africa
# /wiki/Cornelia,_Free_State
# /wiki/Harrismith
# /wiki/Wool
# /wiki/Mackinaw_cloth
# /wiki/Ghalamkar
# /wiki/Pedana_Kalamkari
# /wiki/India
# /wiki/Flora_of_India
# /wiki/Conservation_areas_of_India
# /wiki/Maharashtra
# /wiki/Prahlad_Keshav_Atre
# /wiki/2nd_National_Film_Awards
# /wiki/63rd_National_Film_Awards
# /wiki/National_Film_Award_for_Best_Feature_Film_in_Malayalam
# /wiki/Directorate_of_Film_Festivals
# /wiki/National_Film_Archive_of_India
# /wiki/Direct-to-home_television_in_India
# /wiki/Free-to-air
# /wiki/Western_Australia
# /wiki/Melbourne_University_Press
# /wiki/List_of_university_presses
# /wiki/University_of_Akron_Press
# /wiki/Medina,_Ohio
# /wiki/Latino_(U.S._Census)
# /wiki/Equal_Employment_Opportunity_Commission
# /wiki/United_States_House_of_Representatives_elections,_1950
# /wiki/John_A._Whitaker
# /wiki/Brent_Spence
# /wiki/75th_United_States_Congress
# /wiki/Peter_J._De_Muth
# /wiki/Pennsylvania%27s_30th_congressional_district
# /wiki/Pennsylvania%27s_27th_congressional_district
# /wiki/J._N._Langham
# /wiki/Biographical_Directory_of_the_United_States_Congress
# /wiki/Office_of_the_Clerk
# /wiki/Suspension_of_the_rules_in_the_United_States_Congress
# /wiki/Veto_override
# /wiki/Constitutional_Court_of_Hungary
# /wiki/Hungary
# /wiki/Zalaegerszeg
# /wiki/Demographic_explosion
# /wiki/Standard_of_living
# /wiki/Education
# /wiki/Anatomy
# /wiki/Thorax_(insect_anatomy)
# /wiki/Cephalothorax
# /wiki/Ceratogyrus_darlingi
# /wiki/Lesotho
# /wiki/Basutoland
# /wiki/Moshoeshoe_I
# /wiki/Joseph_G%C3%A9rard
# /wiki/Missionary_Oblates_of_Mary_Immaculate
# /wiki/Maryknoll
# /wiki/De_La_Salle_Brothers
# /wiki/Idiorrhythmic_monasticism
# /wiki/Philosophy
# /wiki/Buddhist_logic
# /wiki/Dharmakirti
# /wiki/Buddhism_in_Singapore
# /wiki/Relics_associated_with_Buddha
# /wiki/Dzogchen
# /wiki/Buddhism_and_evolution
# /wiki/Vihara
# /wiki/Buddhism
# /wiki/Dukkha
# /wiki/Buddhist_texts
# /wiki/Rinpoche
# /wiki/THL_Simplified_Phonetic_Transcription
# /wiki/Standard_Tibetan
# /wiki/Guiqiong_language
# /wiki/Wa_language
# /wiki/Zibusi_language
# /wiki/Tai_L%C3%BC_language
# /wiki/Austroasiatic_languages
# /wiki/Jah_Hut_language
# /wiki/Fuqing_dialect
# /wiki/Leizhou_Min
# /wiki/Leizhou_Peninsula
# /wiki/Stratovolcano
# /wiki/Island_arc
# /wiki/Hellenic_arc
# /wiki/Aegean_Sea_Plate
# /wiki/North_Galapagos_Microplate
# /wiki/Futuna_Plate
# /wiki/Kermadec_Plate
# /wiki/Molucca_Sea_Plate
# /wiki/Banda_Sea
# /wiki/Banda_Sea_Plate
# /wiki/Kerguelen_Plateau
# /wiki/Oceania
# /wiki/Adelaide
# /wiki/Coopers_Brewery
# /wiki/Gas_turbine
# /wiki/Extended-range_electric_vehicle
# /wiki/Transmission_(mechanics)
# /wiki/Speed
# /wiki/Action_(physics)
# /wiki/Gerald_Jay_Sussman
# /wiki/Terry_Winograd
# /wiki/Google
# /wiki/Google_Hangouts
# /wiki/IMVU
# /wiki/Read_Write_Web
# /wiki/Ars_Technica
# /wiki/Epicurious
# /wiki/Reddit
# /wiki/Vogue_India
# /wiki/Advance_Publications#Condé_Nast_Digital
# /wiki/Men%27s_Vogue
# /wiki/The_Jersey_Journal
# /wiki/Jane_(magazine)
# /wiki/Bright_House_Networks
# /wiki/Champion_Broadband
# /wiki/Go90
# /wiki/Television_program
# /wiki/Broadcast_network
# /wiki/Television_studio
# /wiki/Television_station
# /wiki/Broadcast_programming
# /wiki/Television_channel
# /wiki/Telex
# /wiki/ARPANET
# /wiki/TCP/IP
# /wiki/Internet_Group_Management_Protocol
# /wiki/Internet_layer
# /wiki/IPv4
# /wiki/ICMPv6
# /wiki/Datagram_Congestion_Control_Protocol
# /wiki/Bit
# /wiki/Science_(journal)
# /wiki/Spiral_nebulae
# /wiki/Molecular_clouds
# /wiki/Galactic_coordinate_system
# /wiki/Leo_V_(dwarf_galaxy)
# /wiki/Perseus_Arm
# /wiki/Supermassive_black_hole
# /wiki/Naked_singularity
# /wiki/Event_horizon
# /wiki/Principle_of_relativity
# /wiki/Speed_of_light
# /wiki/Refractive_index_of_air
# /wiki/Kyoto_Protocol
# /wiki/Cameroon
# /wiki/Swaziland
# /wiki/Zambia
# /wiki/List_of_newspapers_in_Zambia
# /wiki/List_of_newspapers_in_Botswana
# /wiki/Stellaland
# /wiki/Sharpeville_massacre
# /wiki/Sten
# /wiki/Muzzle_velocity
# /wiki/Artillery
# /wiki/Catapult
# /wiki/Torsion_siege_engine
# /wiki/Carroballista
# /wiki/Ancient_Rome
# /wiki/Fresco
# /wiki/Wawel_Cathedral
# /wiki/Roman_Catholic
# /wiki/Vatican_Council_II
# /wiki/Pope_John_XXIII
# /wiki/John_the_Apostle
# /wiki/John%27s_vision_of_the_Son_of_Man
# /wiki/Revelation_1
# /wiki/Revelation_13
# /wiki/Jezebel
# /wiki/The_Handmaid%27s_Tale
# /wiki/University_of_Toronto
# /wiki/Satellite_campus
# /wiki/Ikeja
# /wiki/Apapa
# /wiki/Lagos_State_Ministry_of_Science_and_Technology
# /wiki/Lagos_State
# /wiki/Akinwunmi_Ambode
# /wiki/Auditor_General
# /wiki/Auditor-General_of_New_South_Wales
# /wiki/Wayback_Machine
# /wiki/Bibliotheca_Alexandrina
# /wiki/Mallawi_Museum
# /wiki/Gamal_Abdel_Nasser_Museum
# /wiki/Bibliotheca_Alexandrina
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Louis_XIV_of_France
# /wiki/Gibraltar
# /wiki/Operation_Flavius
# /wiki/Drumcree_conflict
# /wiki/Peace_line
# /wiki/Rusk_documents
# /wiki/Ieodo
# /wiki/Taiwan
# /wiki/Lust,_Caution
# /wiki/Tony_Leung_Chiu-Wai
# /wiki/Clark_Gable
